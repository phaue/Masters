# %%
##Calculation of the fractions and their errors of a single proton emission from 22Mg to 21Na and from 21Na to 20Ne

# %%
import numpy as np

# %%
Na21 =20.997654459
Na21_err = 0.000000045
p = 1.0078250190
p_err = 0.0000000010
frac = (Na21/(p+Na21))
frac_err = np.sqrt((p/(Na21+p)**2)**2 * Na21_err**2 + (Na21/(p+Na21)**2)**2 * p_err**2)
psep = 5504.10
psep_err = 0.16
frac, frac_err
# Out:
# (0.9542011788469517, 1.032071836027589e-10)

# %%
Ne20 =19.99244017525
Ne20_err = 0.00165/1e6
p = 1.0078250190
p_err = 0.0000000010
frac = (Ne20/(2*p+Ne20))
frac_err = (2 / (2*p + Ne20)**2) * np.sqrt((Ne20**2 * p_err**2) + (p**2 * Ne20_err**2))
psep = 5504.10
psep_err = 0.16
frac, frac_err
# Out:
# (0.9084132235705543, 8.283773719285773e-11)
